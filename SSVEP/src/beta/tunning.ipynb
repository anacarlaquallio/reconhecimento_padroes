# %% [markdown]
# ### Visualização dos dados
# Os gráficos abaixo mostram para os 40 targets o momento em que há o estímulo do SSVEP durante o período de 0,5 - 2,5 segundos. Isso é importante para entender a taxa de acurácia do participante em questão.
# A partir do RFE, foi possível obter aproximadamente 66.67% de acurácia e, com os gráficos abaixo, nota-se que há frequências que não são estimuladas no ponto correto, como o gráfico que contém 9.0 e 8.4. O
# A acurácia de 66.67% sugere que 33.33% dos dados do participante 3 não estão estão sendo estimulados na frequência devida. Porém, há poucos pontos que estão incorretos nos gráficos. Desse modo, talvez seja possível aumentar ainda mais a taxa de acerto para o participante em questão.
# É válido ressaltar que os dados foram normalizados e aplicou-se validação cruzada para a seleção manual. Uma possiblidade de melhora de acurácia seria testar validação cruzada com RFE (RFECV), porém demoraria um tempo significativo para o processamento.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.io import loadmat

# %%
info = loadmat("../../datasets/beta/S3.mat")['data']

# %%
eeg_data = info[0][0][0]
print(eeg_data.shape)
data = info[0][0][1][0][0]

chs = [d[3][0] for d in data[3]]
labels = data[4][0]
eeg = eeg_data.transpose(3, 2, 0, 1)

print(len(chs), chs)
print(labels.shape, labels)
print(eeg.shape)
# Out:
# (64, 750, 4, 40)
# 64 ['FP1', 'FPZ', 'FP2', 'AF3', 'AF4', 'F7', 'F5', 'F3', 'F1', 'FZ', 'F2', 'F4', 'F6', 'F8', 'FT7', 'FC5', 'FC3', 'FC1', 'FCZ', 'FC2', 'FC4', 'FC6', 'FT8', 'T7', 'C5', 'C3', 'C1', 'CZ', 'C2', 'C4', 'C6', 'T8', 'M1', 'TP7', 'CP5', 'CP3', 'CP1', 'CPZ', 'CP2', 'CP4', 'CP6', 'TP8', 'M2', 'P7', 'P5', 'P3', 'P1', 'PZ', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO5', 'PO3', 'POZ', 'PO4', 'PO6', 'PO8', 'CB1', 'O1', 'OZ', 'O2', 'CB2']
# (40,) [ 8.6  8.8  9.   9.2  9.4  9.6  9.8 10.  10.2 10.4 10.6 10.8 11.  11.2
#  11.4 11.6 11.8 12.  12.2 12.4 12.6 12.8 13.  13.2 13.4 13.6 13.8 14.
#  14.2 14.4 14.6 14.8 15.  15.2 15.4 15.6 15.8  8.   8.2  8.4]
# (40, 4, 64, 750)

# %%
# média dos 4 blocos
eeg2 = np.average(eeg, axis=1)
print(eeg2.shape)

# separando os eletrodos entendidos como "bons": Pz, PO3, PO5, PO4, PO6, POz, 
# O1, Oz e O2.
print([(i, ch) for i, ch in enumerate(chs)])
eeg3 = eeg2[:, [47, 54, 53, 56, 57, 55, 60, 61, 62]]
print(eeg3.shape)

# média dos 9 eletrodos escolhidos
eeg4 = np.average(eeg3, axis=1)
print(eeg4.shape)

# dados sem a parte basal
X = eeg4[:, 125:-125]
print(X.shape)
# Out:
# (40, 64, 750)
# [(0, 'FP1'), (1, 'FPZ'), (2, 'FP2'), (3, 'AF3'), (4, 'AF4'), (5, 'F7'), (6, 'F5'), (7, 'F3'), (8, 'F1'), (9, 'FZ'), (10, 'F2'), (11, 'F4'), (12, 'F6'), (13, 'F8'), (14, 'FT7'), (15, 'FC5'), (16, 'FC3'), (17, 'FC1'), (18, 'FCZ'), (19, 'FC2'), (20, 'FC4'), (21, 'FC6'), (22, 'FT8'), (23, 'T7'), (24, 'C5'), (25, 'C3'), (26, 'C1'), (27, 'CZ'), (28, 'C2'), (29, 'C4'), (30, 'C6'), (31, 'T8'), (32, 'M1'), (33, 'TP7'), (34, 'CP5'), (35, 'CP3'), (36, 'CP1'), (37, 'CPZ'), (38, 'CP2'), (39, 'CP4'), (40, 'CP6'), (41, 'TP8'), (42, 'M2'), (43, 'P7'), (44, 'P5'), (45, 'P3'), (46, 'P1'), (47, 'PZ'), (48, 'P2'), (49, 'P4'), (50, 'P6'), (51, 'P8'), (52, 'PO7'), (53, 'PO5'), (54, 'PO3'), (55, 'POZ'), (56, 'PO4'), (57, 'PO6'), (58, 'PO8'), (59, 'CB1'), (60, 'O1'), (61, 'OZ'), (62, 'O2'), (63, 'CB2')]
# (40, 9, 750)
# (40, 750)
# (40, 500)

# %%
for i in range(40):
    
    target = float(f"{labels[i]:.1f}")
    w = np.fft.fft(X, axis=1)
    freqs = np.fft.fftfreq(X.shape[1], (1 / 250))

    plt.figure(figsize=(8, 4))
    plt.plot(freqs, np.abs(w[i]))
    plt.xlabel('Frequência (Hz)')
    plt.ylabel('Amplitude')
    plt.xlim(0, 60)
    plt.axvline(x=target, linestyle='--', linewidth=.8, color='red')
    plt.text(target + 0.5, np.max(np.abs(w[i]))-10, str(target), color='red')
    plt.grid()
    plt.show()
